# %% [markdown]
# # ORDER_ANALYISIS

# %% [markdown]
# # ABOUT THE DATASET

# %% [markdown]
# ## The Dataset contains OrderDate, Region, Rep, Item, unit, unit cost and Total columns in the dataset. As a data analyst I have to find insights that will help answer stakeholders questions.

# %% [markdown]
# # QUESTIONS :

# %% [markdown]
# ## I will write SQL queries on MySQL workbench to find insights regarding Questions asked :

# %% [markdown]
# ## 1.What is the total revenue generated for each region?

# %% [markdown]
# ![2023-05-18.png](attachment:2023-05-18.png)

# %% [markdown]
# ## 2.Which item had the highest sales volume?

# %% [markdown]
# ![2023-05-18%20%281%29.png](attachment:2023-05-18%20%281%29.png)

# %% [markdown]
# ## 3.Who is the top-performing sales representative based on total sales?

# %% [markdown]
# ![2023-05-18%20%282%29.png](attachment:2023-05-18%20%282%29.png)

# %% [markdown]
# ## 4. How many units of each item were sold in a specific region?

# %% [markdown]
# ### For East region:

# %% [markdown]
# ![2023-05-18%20%283%29.png](attachment:2023-05-18%20%283%29.png)

# %% [markdown]
# ## For Central region

# %% [markdown]
# ![2023-05-18%20%284%29.png](attachment:2023-05-18%20%284%29.png)

# %% [markdown]
# ## For west region

# %% [markdown]
# ![2023-05-18%20%285%29.png](attachment:2023-05-18%20%285%29.png)

# %% [markdown]
# ## 5. Which region had the highest total sales?

# %% [markdown]
# ![2023-05-18%20%286%29.png](attachment:2023-05-18%20%286%29.png)

# %% [markdown]
# ## 6.Which sales representative had the highest average sales per order?

# %% [markdown]
# ![2023-05-19.png](attachment:2023-05-19.png)

# %% [markdown]
# ## 7.How many units were ordered of each Items and what revenue they generated ?

# %% [markdown]
# ![2023-05-20.png](attachment:2023-05-20.png)

# %% [markdown]
# ## 8.How many orders were placed in different regions?

# %% [markdown]
# ![2023-05-20%20%281%29.png](attachment:2023-05-20%20%281%29.png)

# %% [markdown]
# ## 9.Which Sales representative attended most Orders ?

# %% [markdown]
# ![2023-05-20%20%282%29.png](attachment:2023-05-20%20%282%29.png)

# %% [markdown]
# ## 10.Total Revenue generated ?

# %% [markdown]
# ![2023-05-20%20%283%29.png](attachment:2023-05-20%20%283%29.png)
